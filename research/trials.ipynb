# %%
import yaml
with open("test.yaml",'r') as file:
    data=yaml.safe_load(file)
data
# Out:
# 'name:Aswhini Kakde email:kakdeashwini12@gmail.com'

# %%
import yaml
from box import ConfigBox

# Load data from YAML file
with open("test.yaml", 'r') as file:
    data = yaml.safe_load(file)

# Print data to check its structure
print(data)  # This should print: {'name': 'Aswhini Kakde', 'email': 'kakdeashwini12@gmail.com'}

# Convert the data to ConfigBox
d = ConfigBox(data)

# Access data
print(d.name)  # Output: Aswhini Kakde
print(d.email)  # Output: kakdeashwini12@gmail.com
# Out:
# name:Aswhini Kakde email:kakdeashwini12@gmail.com
